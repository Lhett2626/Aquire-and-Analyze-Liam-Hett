# %%
import requests
import json
import time
import pandas as pd

#API Key is in the copy

class GoogleGeocode(object):
    def __init__(self, GeoapiKey):
        super(GoogleGeocode, self).__init__()
        self.apiKey = GeoapiKey
        
    def get_coordinates(self, address):
        endpoint_url = 'https://maps.googleapis.com/maps/api/geocode/json'
        params = {
            'address': address,
            'key': self.apiKey
        }
        res = requests.get(endpoint_url, params = params)
        georesults =  json.loads(res.content)
        lat = georesults['results'][0]['geometry']['location']['lat']
        lng = georesults['results'][0]['geometry']['location']['lng']
        cordinates = str(lat) + ',' + str(lng)
        return(cordinates)

# %%
class GooglePlaces(object):
    def __init__(self, apiKey):
        super(GooglePlaces, self).__init__()
        self.apiKey = apiKey
 
    def search_places_by_coordinate(self, location, types):
        endpoint_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?"
        places = []
        params = {
            'location': location,
            'types': types,
            'rankby' : 'distance',
            'key': self.apiKey
        }
        res = requests.get(endpoint_url, params = params)
        results =  json.loads(res.content)
        places.extend(results['results'])
        time.sleep(2)
        
        while "next_page_token" in results:
            params['pagetoken'] = results['next_page_token'],
            res = requests.get(endpoint_url, params = params)
            results = json.loads(res.content)
            places.extend(results['results'])
            time.sleep(2)
        
        return(places)

    
    def get_place_details(self, place_id, fields):
        endpoint_url = "https://maps.googleapis.com/maps/api/place/details/json"
        params = {
            'placeid': place_id,
            'fields': ",".join(fields),
            'key': self.apiKey
        }
        res = requests.get(endpoint_url, params = params)
        place_details =  json.loads(res.content)
        return(place_details)

# %%
geoapi = GoogleGeocode(GeoapiKey)

# %%
cordinates = geoapi.get_coordinates('Missoula')

# %%
cordinates
# Out:
# '46.8721284,-113.9940314'

# %%
api = GooglePlaces(apiKey)

# %%
places = api.search_places_by_coordinate(cordinates, types = 'restaurant')

# %%
places

# %% [markdown]
# Big limitation can only resturn 60 results. They used to have a radar search that would return 200 results. It was taken down. Google has it posted all over the web that workarounds are agianst their service terms to prevent web scraping. I decided not to take this risk.

# %%
len(places)
# Out:
# 60

# %%
fields = ['name', 'user_ratings_total', 'formatted_address', 'opening_hours', 'permanently_closed', 'price_level', 'international_phone_number', 'website', 'rating', 'review']

# %%
for place in places:
    try:
        details = api.get_place_details(place['place_id'], fields)
        #name = details['result']['name']
        rest_info = pd.json_normalize(details)
        restaurants = restaurants.append(rest_info)
    except:
        details = api.get_place_details(place['place_id'], fields)
        restaurants = pd.json_normalize(details)

# %%
len(restaurants)
# Out:
# 60

# %%
restaurants.drop(['html_attributions',
                  'status',
                  'result.opening_hours.open_now',
                  'result.opening_hours.periods']
                 , axis=1, inplace=True)

# %%
restaurants.rename(columns = {'result.formatted_address':'Address', 
                              'result.international_phone_number':'Phone_Number', 
                              'result.name':'Name',
                              'result.opening_hours.weekday_text': 'Hours_Open',
                              'result.price_level' : 'Price_level',
                              'result.reviews' : 'reviews',
                              'result.website' : 'website',
                              'result.rating': 'Rating',
                              'result.user_ratings_total': '#_of_Ratings'}, inplace = True)

# %%
restaurants = restaurants.set_index('Name')

# %%
restaurants
# Out:
#                                                                             Address  \
# Name
# Clove Cart Pizza                         Mobile Pizza Oven, Missoula, MT 59802, USA
# Pangea Bar & Restaurant Missoula         223 N Higgins Ave, Missoula, MT 59802, USA
# The Depot                                201 Railroad St W, Missoula, MT 59802, USA
# Brooks & Browns Bar & Grill                200 S Pattee St, Missoula, MT 59802, USA
# Kakigōri Bar                               516 E Spruce St, Missoula, MT 59802, USA
# River Wok Asian Grill                    624 E Broadway St, Missoula, MT 59802, USA
# Subway                                   624 E Broadway St, Missoula, MT 59802, USA
# Taco Bell                                651 E Broadway St, Missoula, MT 59802, USA
# GILD                                     515 S Higgins Ave, Missoula, MT 59801, USA
# Ciao Mambo                               541 S Higgins Ave, Missoula, MT 59801, USA
# 4B's Restaurant                          700 E Broadway St, Missoula, MT 59802, USA
# FINN                                        100 Madison St, Missoula, MT 59802, USA
# Burger King                              701 E Broadway St, Missoula, MT 59802, USA
#
#                                      Phone_Number  \
# Name
# Clove Cart Pizza                  +1 617-571-6894
# Pangea Bar & Restaurant Missoula  +1 406-493-1190
# Plonk Missoula                    +1 406-926-1791
# Liquid Planet - Downtown          +1 406-541-4541
# Five on Black                     +1 406-926-1860
# Doc's Sandwich Shop               +1 406-542-7414
# The Oxford Cafe                   +1 406-549-0117
# Locals                            +1 406-543-0646
# Sushi Hana Downtown               +1 406-549-7979
# Red's Bar                         +1 406-728-9881
# The Empanada Joint                +1 406-926-1120
# Thomas Meagher Bar                +1 406-540-4402
# Missoula Club                     +1 406-728-3740
# Conflux Brewing Company           +1 406-926-3589
# Thyme Out Cafe & Local Market     +1 406-214-2424
# Jimmy John's                      +1 406-542-1100
# Taco del Sol                      +1 406-327-8929
# Masala                            +1 406-926-6444
# Sa-Wa-Dee Thai Restaurant         +1 406-543-9966
# Union Club Bar                    +1 406-728-7980
# Basal                             +1 406-540-4098
# Charlie B's                       +1 406-549-3589
# Dinosaur Cafe                     +1 406-721-3808
# The Catalyst Cafe                 +1 406-542-1337
# Second Set Bistro                 +1 406-830-3233
# Golden Yolk Griddle               +1 406-926-1145
# The Shack Cafe                    +1 406-549-9903
# Worden's Market & Deli            +1 406-549-1293
# The Old Post                      +1 406-540-4433
# 1889 Steakhouse                   +1 406-529-1263
# Top Hat                           +1 406-728-9865
# Zoo Thai                          +1 406-540-4206
# Cranky Sam Public House           +1 406-540-4325
# The Camino                        +1 406-317-1260
# Biga Pizza                        +1 406-728-2579
# HuHot Franchise Office            +1 406-251-4303
# El Cazador                        +1 406-728-3657
# Saketome                          +1 406-926-2555
# Dobi’s Teriyaki                   +1 406-926-1661
# Michi Ramen Bar                   +1 406-926-1186
# Market on Front                   +1 406-541-0246
# The Notorious P.I.G. BBQ          +1 406-926-1344
# Pie Hole                          +1 406-926-2233
# Mountain Berry Bowls Missoula     +1 404-583-9822
# Scotty's Table                    +1 406-549-2790
# Brasserie Porte Rouge                         NaN
# Tandem Bakery                     +1 406-239-3997
# Front St. Pizza                   +1 406-303-4660
# Wally and Buck                    +1 406-549-8157
# The Depot                         +1 406-728-7007
# Brooks & Browns Bar & Grill       +1 406-532-2056
# Kakigōri Bar                      +1 406-303-4334
# River Wok Asian Grill             +1 406-721-2673
# Subway                            +1 406-721-5620
# Taco Bell                         +1 406-728-6667
# GILD                              +1 406-926-3258
# Ciao Mambo                        +1 406-543-0377
# 4B's Restaurant                   +1 406-926-2364
# FINN                              +1 406-542-4660
# Burger King                       +1 406-542-0223
#
#                                                                          Hours_Open  \
# Name
# Clove Cart Pizza                  [Monday: Closed, Tuesday: Closed, Wednesday: 1...
# Pangea Bar & Restaurant Missoula  [Monday: 11:00 AM – 10:00 PM, Tuesday: 11:00 A...
Monday: 11:00 AM – 9:00 PM, Tuesday: 11:00 AM...
# Saketome                          [Monday: 5:00 – 10:00 PM, Tuesday: Closed, Wed...
# Dobi’s Teriyaki                   [Monday: 4:30 – 8:00 PM, Tuesday: 11:00 AM – 8...
# Michi Ramen Bar                   [Monday: 11:00 AM – 11:00 PM, Tuesday: Closed,...
# Market on Front                   [Monday: 7:00 AM – 8:00 PM, Tuesday: 7:00 AM –...
# The Notorious P.I.G. BBQ          [Monday: Closed, Tuesday: 11:00 AM – 8:00 PM, ...
# Pie Hole                          [Monday: 11:00 AM – 3:00 AM, Tuesday: 11:00 AM...
# Mountain Berry Bowls Missoula                                                   NaN
# Scotty's Table                    [Monday: Closed, Tuesday: Closed, Wednesday: 1...
# Brasserie Porte Rouge                                                           NaN
# Tandem Bakery                     [Monday: 12:30 – 5:00 PM, Tuesday: 12:30 – 5:0...
# Front St. Pizza                   [Monday: 11:30 AM – 9:00 PM, Tuesday: 11:30 AM...
# Wally and Buck                    [Monday: Closed, Tuesday: 11:30 AM – 9:00 PM, ...
# The Depot                         [Monday: Closed, Tuesday: 4:30 – 9:30 PM, Wedn...
# Brooks & Browns Bar & Grill                                                     NaN
# Kakigōri Bar                      [Monday: Closed, Tuesday: Closed, Wednesday: C...
# River Wok Asian Grill             [Monday: 11:00 AM – 9:00 PM, Tuesday: 11:00 AM...
# Subway                            [Monday: 9:00 AM – 9:00 PM, Tuesday: 9:00 AM –...
# Taco Bell                         [Monday: 8:00 AM – 7:00 PM, Tuesday: 8:00 AM –...
# GILD                              [Monday: 11:00 AM – 10:00 PM, Tuesday: 11:00 A...
# Ciao Mambo                        [Monday: Closed, Tuesday: 5:00 – 9:00 PM, Wedn...
# 4B's Restaurant                   [Monday: 7:00 AM – 6:00 PM, Tuesday: 7:00 AM –...
# FINN                              [Monday: 7:00 – 11:00 AM, 4:00 – 9:00 PM, Tues...
# Burger King                       [Monday: 6:00 AM – 12:00 AM, Tuesday: 6:00 AM ...
#
#                                   Rating  \
# Name
# Clove Cart Pizza                     5.0
# Pangea Bar & Restaurant Missoula     4.2
# Plonk Missoula                       4.5
# Liquid Planet - Downtown             4.4
# Five on Black                        4.7
# Doc's Sandwich Shop                  4.2
# The Oxford Cafe                      4.3
# Locals                               4.0
# Sushi Hana Downtown                  4.2
# Red's Bar                            4.4
# The Empanada Joint                   4.2
# Thomas Meagher Bar                   4.4
# Missoula Club                        4.4
# Conflux Brewing Company              4.2
# Thyme Out Cafe & Local Market        5.0
# Jimmy John's                         3.9
# Taco del Sol                         4.4
# Masala                               4.4
# Sa-Wa-Dee Thai Restaurant            4.4
# Union Club Bar                       4.4
# Basal                                4.7
# Charlie B's                          4.6
# Dinosaur Cafe                        4.6
# The Catalyst Cafe                    4.6
# Second Set Bistro                    4.7
# Golden Yolk Griddle                  4.7
# The Shack Cafe                       4.3
# Worden's Market & Deli               4.5
# The Old Post                         4.3
# 1889 Steakhouse                      4.2
# Top Hat                              4.5
# Zoo Thai                             4.4
# Cranky Sam Public House              4.8
# The Camino                           4.4
# Biga Pizza                           4.7
# HuHot Franchise Office               2.6
# El Cazador                           4.3
# Saketome                             4.4
# Dobi’s Teriyaki                      4.8
# Michi Ramen Bar                      4.4
# Market on Front                      4.4
# The Notorious P.I.G. BBQ             4.7
# Pie Hole                             4.4
# Mountain Berry Bowls Missoula        4.8
# Scotty's Table                       4.5
# Brasserie Porte Rouge                NaN
# Tandem Bakery                        5.0
# Front St. Pizza                      4.5
# Wally and Buck                       4.7
# The Depot                            4.3
# Brooks & Browns Bar & Grill          3.6
# Kakigōri Bar                         5.0
# River Wok Asian Grill                3.3
# Subway                               3.7
# Taco Bell                            3.8
# GILD                                 4.6
# Ciao Mambo                           4.5
# 4B's Restaurant                      4.2
# FINN                                 4.3
# Burger King                          3.1
#
#                                                                             reviews  \
# Name
# Clove Cart Pizza                  [{'author_name': 'Jennifer Trimble', 'author_u...
# Pangea Bar & Restaurant Missoula  [{'author_name': 'Brian Logsdon', 'author_url'...
# Plonk Missoula                    [{'author_name': 'Gloria heintz', 'author_url'...
# Liquid Planet - Downtown          [{'author_name': 'Lacy Z', 'author_url': 'http...
# Five on Black                     [{'author_name': 'J T', 'author_url': 'https:/...
# Doc's Sandwich Shop               [{'author_name': 'Jesse Franzen', 'author_url'...
# The Oxford Cafe                   [{'author_name': 'Trevor Anderson', 'author_ur...
# Locals                            [{'author_name': 'Lyle Masterson', 'author_url...
# Sushi Hana Downtown               [{'author_name': 'Timothy Michael Ufferman', '...
# Red's Bar                         [{'author_name': 'Emily Danger', 'author_url':...
# The Empanada Joint                [{'author_name': 'Joe M', 'author_url': 'https...
# Thomas Meagher Bar                [{'author_name': 'Trenton Thomas', 'author_url...
# Missoula Club                     [{'author_name': 'Kay Lynne', 'author_url': 'h...
# Conflux Brewing Company           [{'author_name': 'Norma Arnold', 'author_url':...
# Thyme Out Cafe & Local Market     [{'author_name': 'Eric Lehman', 'author_url': ...
# Jimmy John's                      [{'author_name': 'Tim Haight', 'author_url': '...
# Taco del Sol                      [{'author_name': 'BC orange man bad Obv', 'aut...
# Masala                            [{'author_name': 'Very Oliver Raft', 'author_u...
# Sa-Wa-Dee Thai Restaurant         [{'author_name': 'Christine IsAQueen', 'author...
# Union Club Bar                    [{'author_name': 'Paul Mora', 'author_url': 'h...
# Basal                             [{'author_name': 'June Pearl', 'author_url': '...
# Charlie B's                       [{'author_name': 'Claire MacDonald', 'author_u...
# Dinosaur Cafe                     [{'author_name': 'Lavishing Ironic', 'author_u...
# The Catalyst Cafe                 [{'author_name': 'Chris Haines', 'author_url':...
# Second Set Bistro                 [{'author_name': 'S M', 'author_url': 'https:/...
# Golden Yolk Griddle               [{'author_name': 'Christian Benz', 'author_url...
# The Shack Cafe                    [{'author_name': 'Megan Zmak', 'author_url': '...
# Worden's Market & Deli            [{'author_name': 'madelein heaven', 'author_ur...
# The Old Post                      [{'author_name': 'Paula Lemon', 'author_url': ...
# 1889 Steakhouse                   [{'author_name': 'Tim Mitchell', 'author_url':...
# Top Hat                           [{'author_name': 'Jonathan Bond', 'author_url'...
# Zoo Thai                          [{'author_name': 'EarthDeNeal', 'author_url': ...
# Cranky Sam Public House           [{'author_name': 'Alexandra Akmal', 'author_ur...
# The Camino                        [{'author_name': 'Everett Headley', 'author_ur...
# Biga Pizza                        [{'author_name': 'Mike Barts', 'author_url': '...
# HuHot Franchise Office            [{'author_name': 'Lex Kelly', 'author_url': 'h...
# El Cazador                        [{'author_name': 'KINGDOM MT', 'author_url': '...
# Saketome                          [{'author_name': 'Kayla Noel', 'author_url': '...
# Dobi’s Teriyaki                   [{'author_name': 'Patrick Lucas', 'author_url'...
# Michi Ramen Bar                   [{'author_name': 'Tori Thayer', 'author_url': ...
# Market on Front                   [{'author_name': 'David Campbell', 'author_url...
# The Notorious P.I.G. BBQ          [{'author_name': 'Darin Stevens', 'author_url'...
# Pie Hole                          [{'author_name': 'Joshua Boyd', 'author_url': ...
# Mountain Berry Bowls Missoula     [{'author_name': 'Martin KaLdahl', 'author_url...
# Scotty's Table                    [{'author_name': 'Daria O'Brien', 'author_url'...
# Brasserie Porte Rouge                                                           NaN
# Tandem Bakery                     [{'author_name': 'Lise Smith', 'author_url': '...
# Front St. Pizza                   [{'author_name': 'Dianna', 'author_url': 'http...
# Wally and Buck                    [{'author_name': 'Rio Baroch', 'author_url': '...
# The Depot                         [{'author_name': 'Deidre Vanderpool', 'author_...
# Brooks & Browns Bar & Grill       [{'author_name': 'T C', 'author_url': 'https:/...
# Kakigōri Bar                      [{'author_name': 'B k', 'author_url': 'https:/...
# River Wok Asian Grill             [{'author_name': 'Hanna Kollbaum', 'author_url...
# Subway                            [{'author_name': 'Jim Huggins', 'author_url': ...
# Taco Bell                         [{'author_name': 'Kathy Munson', 'author_url':...
# GILD                              [{'author_name': 'Renata Cayton', 'author_url'...
# Ciao Mambo                        [{'author_name': 'Brooke Nelson', 'author_url'...
# 4B's Restaurant                   [{'author_name': 'Miya Ensley', 'author_url': ...
# FINN                              [{'author_name': 'Jon Black', 'author_url': 'h...
# Burger King                       [{'author_name': 'Tahy Swag', 'author_url': 'h...
#
#                                   #_of_Ratings  \
# Name
# Clove Cart Pizza                           5.0
# Pangea Bar & Restaurant Missoula         161.0
# Plonk Missoula                           513.0
# Liquid Planet - Downtown                 449.0
# Five on Black                            917.0
# Doc's Sandwich Shop                      234.0
# The Oxford Cafe                          836.0
# Locals                                    22.0
# Sushi Hana Downtown                      621.0
# Red's Bar                                141.0
# The Empanada Joint                        77.0
# Thomas Meagher Bar                      1093.0
# Missoula Club                            531.0
# Conflux Brewing Company                  304.0
# Thyme Out Cafe & Local Market              1.0
# Jimmy John's                             148.0
# Taco del Sol                             152.0
# Masala                                   456.0
# Sa-Wa-Dee Thai Restaurant                189.0
# Union Club Bar                           405.0
# Basal                                    109.0
# Charlie B's                              286.0
# Dinosaur Cafe                            110.0
# The Catalyst Cafe                        558.0
# Second Set Bistro                        106.0
# Golden Yolk Griddle                       28.0
# The Shack Cafe                           414.0
# Worden's Market & Deli                   553.0
# The Old Post                             549.0
# 1889 Steakhouse                          199.0
# Top Hat                                 1337.0
# Zoo Thai                                 166.0
# Cranky Sam Public House                  243.0
# The Camino                               230.0
# Biga Pizza                               888.0
# HuHot Franchise Office                     5.0
# El Cazador                               957.0
# Saketome                                 251.0
# Dobi’s Teriyaki                          100.0
# Michi Ramen Bar                          389.0
# Market on Front                          929.0
# The Notorious P.I.G. BBQ                1060.0
# Pie Hole                                 904.0
# Mountain Berry Bowls Missoula             42.0
# Scotty's Table                           275.0
# Brasserie Porte Rouge                      NaN
# Tandem Bakery                             36.0
# Front St. Pizza                           82.0
# Wally and Buck                           223.0
# The Depot                                664.0
# Brooks & Browns Bar & Grill               63.0
# Kakigōri Bar                              12.0
# River Wok Asian Grill                     88.0
# Subway                                   119.0
# Taco Bell                                542.0
# GILD                                     539.0
# FINN                                                      https://finnmissoula.com/
# Burger King                       https://burgerking.com/store-locator/store/res...
#
#                                   Price_level result.permanently_closed
# Name
# Clove Cart Pizza                          NaN                       NaN
# Pangea Bar & Restaurant Missoula          NaN                       NaN
# Plonk Missoula                            3.0                       NaN
# Liquid Planet - Downtown                  2.0                       NaN
# Five on Black                             1.0                       NaN
# Doc's Sandwich Shop                       2.0                       NaN
# The Oxford Cafe                           1.0                       NaN
# Locals                                    NaN                       NaN
# Sushi Hana Downtown                       2.0                       NaN
# Red's Bar                                 1.0                       NaN
# The Empanada Joint                        NaN                       NaN
# Thomas Meagher Bar                        2.0                       NaN
# Missoula Club                             1.0                       NaN
# Conflux Brewing Company                   2.0                       NaN
# Thyme Out Cafe & Local Market             NaN                       NaN
# Jimmy John's                              1.0                       NaN
# Taco del Sol                              1.0                      True
# Masala                                    1.0                       NaN
# Sa-Wa-Dee Thai Restaurant                 2.0                       NaN
# Union Club Bar                            1.0                       NaN
# Basal                                     1.0                       NaN
# Charlie B's                               1.0                       NaN
# Dinosaur Cafe                             NaN                       NaN
# The Catalyst Cafe                         2.0                       NaN
# Second Set Bistro                         NaN                       NaN
# Golden Yolk Griddle                       NaN                       NaN
# The Shack Cafe                            2.0                       NaN
# Worden's Market & Deli                    1.0                       NaN
# The Old Post                              1.0                       NaN
# 1889 Steakhouse                           NaN                       NaN
# Top Hat                                   2.0                       NaN
# Zoo Thai                                  NaN                       NaN
# Cranky Sam Public House                   NaN                       NaN
# The Camino                                NaN                       NaN
# Biga Pizza                                2.0                       NaN
# HuHot Franchise Office                    NaN                       NaN
# El Cazador                                1.0                       NaN
# Saketome                                  NaN                       NaN
# Dobi’s Teriyaki                           NaN                       NaN
# Michi Ramen Bar                           NaN                       NaN
# Market on Front                           2.0                       NaN
# The Notorious P.I.G. BBQ                  2.0                       NaN
# Pie Hole                                  1.0                       NaN
# Mountain Berry Bowls Missoula             NaN                      True
# Scotty's Table                            3.0                       NaN
# Brasserie Porte Rouge                     NaN                       NaN
# Tandem Bakery                             NaN                       NaN
# Front St. Pizza                           NaN                       NaN
# Wally and Buck                            NaN                       NaN
# The Depot                                 3.0                       NaN
# Brooks & Browns Bar & Grill               2.0                      True
# Kakigōri Bar                              NaN                       NaN
# River Wok Asian Grill                     NaN                       NaN
# Subway                                    1.0                       NaN
# Taco Bell                                 1.0                       NaN
# GILD                                      2.0                       NaN
# Ciao Mambo                                3.0                       NaN
# 4B's Restaurant                           2.0                       NaN
# FINN                                      NaN                       NaN
# Burger King                               1.0                       NaN

# %%
closed = restaurants[restaurants['result.permanently_closed'] == True].index
restaurants.drop(closed, inplace = True)

# %%
restaurants.drop('result.permanently_closed', axis = 1, inplace= True)

# %%
restaurants = restaurants.sort_values('Rating',  ascending=False)

# %%
restaurants.to_csv('Google_Missoula_Restaurants.csv')

# %%
review_dictionary = {}
for key, value in restaurants.iterrows():
    rest_review = value['reviews']
    if type(rest_review) == float:
        continue
    else:
        review_df = pd.json_normalize(rest_review)
        review_dictionary[key] = review_df

# %%
for key in review_dictionary:
    review_dictionary[key].to_csv('Google_Reviews/' + str(key) + '_Google_reviews.csv')

# %%
len(restaurants)
# Out:
# 57

# %%
restaurants
